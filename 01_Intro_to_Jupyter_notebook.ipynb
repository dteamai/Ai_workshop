# %% [markdown]
# <h1 align='center'>Intro to Jupyter Notebook<h1>

# %% [markdown]
# ## Table of contents
#
# 1.   <a href="#1">What is Jupyter Notebook?</a>
# 2.   <a href="#2">Why do we need Jupyter notebook?</a>
# 3.   <a href="#3">Installing Jupyter Notebook</a>
# 4.   <a href="#4">Running Jupyter notebook</a>
# 5.   <a href="#5">Creating a Notebook</a>
# 6.   <a href="#6">Execute a notebook</a>
# 7.  <a href="#7">Some Special Features</a>
# 8.  <a href="#8">Markdowns</a>
# 9.  <a href="#9">NBConvert</a>
# 10.  <a href="#10">Environment and Jupyter</a>
# 11.  <a href='#11'>Kernel</a>

# %% [markdown]
# ![jupyter.png](attachment:jupyter.png)

# %% [markdown]
# <a id='1'></a>
# ## What is Jupyter Notebook?

# %% [markdown]
# * **Jupyter Notebook** is a web application that allows you to create and share documents that contain:
#
#     * live code (e.g. Python code)
#     * visualizations
#     * explanatory text (written in markdown syntax)

# %% [markdown]
# <a id='2'></a>
# ## Why do we need Jupyter notebook?

# %% [markdown]
# * Jupyter Notebook is great for the following use cases:
#
#     * learn and try out Python
#     * data processing / transformation
#     * numeric simulation
#     * statistical modeling
#     * machine learning

# %% [markdown]
# * The term “notebook” is very applicable, since the tool allows you to write snippets of self-contained executable code (named “cells”), note each procedure, and even visualize data you are working with at any step of the way.

# %% [markdown]
# * Jupyter Notebooks have gained tremendous popularity in the Python data science community over the past years for a variety of reasons

# %% [markdown]
# ### Prototyping of Python Workflows

# %% [markdown]
# ![enniz-bit-256012-1024x682.jpg](attachment:enniz-bit-256012-1024x682.jpg)

# %% [markdown]
# * Jupyter Notebooks are extremely useful when you do not have a defined final process and are still in the prototyping phase of your scripted workflow.
# * This is mainly thanks to the feature where code is written into independent cells, which can each execute independently from the rest of the code.
# * This allows a Python user to quickly test a specific step in a sequential workflow without re-executing code from the beginning of the script.

# %% [markdown]
# * Many Integrated Development Environments (IDEs) allow you to do this in several ways, but I’ve found Jupyter Notebook’s concept of a “code cell” to be the most intuitive approach for prototyping logic and sequential code.

# %% [markdown]
# ### Visualizing Pandas Dataframes

# %% [markdown]
# * Pandas (Python Data Analysis Library) provides high-performing and easy-to-use data structures that allow you to work with large amounts of data extremely fast.
# * The core data object is a Dataframe, which is essentially an in-memory table that allows powerful indexing operations.
#
#
# * Jupyter Notebook allows you to visualize these tables at any point in your notebook.
# * This is extremely useful because you can view the state of your data (and the effect of all the actions your code is performing on your data) as each step of your logic executes.
# * This capability reinforces the use of Jupyter Notebook in a prototyping workflow when you are attempting to confirm that your workflow is doing what it needs to do at each step of the way.

# %% [markdown]
# ![1-HHYlAx2Zb3AR2RAD0feuIw-1024x557.png](attachment:1-HHYlAx2Zb3AR2RAD0feuIw-1024x557.png)

# %%
print('Hello')
# Out:
# Hello

# %%
import numpy as np

# %%
np.zeros()

# %% [markdown]
# <a id='3'></a>
# ## Installing Jupyter Notebook

# %% [markdown]
# * **Get up and running with the jupyter Notebook on you computer within minutes!**

# %% [markdown]
# ### Prerequisite: Python

# %% [markdown]
# * While **Jupyter** runs code in many programming languages, **Python** is a requirement(Python 3.3 or greater, or python 2.7) for installing the jupyter Notebook itself.

# %% [markdown]
# ### Installing Jupyter Using Anaconda

# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %% [markdown]
# * We strongly recommend installing python and jupyter using the Anaconda Distribution, which includes Python, the jupyter Notebook, and other commonly used packages for scientific computing and data Science.

# %% [markdown]
# * First download Anaconda. We recommend Downloading Anaconda's latest Python 3 version

# %% [markdown]
# * Second install the version of Anaconda which you downloaded, following the instructions on the download page.

# %% [markdown]
# * For Linux users:
#     * https://www.anaconda.com/download/#linux
#     * https://docs.anaconda.com/anaconda/install/linux
# * For windows users:
#     * https://www.anaconda.com/download/#windows
#     * https://docs.anaconda.com/anaconda/install/windows

# %% [markdown]
# ### Installing Jupyter with pip

# %% [markdown]
# * As an existing or experienced Python user, you may wish to install jupyter using Python's package manager pip, instead of Anaconda.

# %% [markdown]
# * If you have Python3 installed (which is recommended):
#     * #### pip3 install --upgrade pip
#     * #### pip3 install jupyter

# %% [markdown]
# <a id='4'></a>
# ## Running Jupyter notebook

# %% [markdown]
# * To run the notebook, run the following command at the Terminal(Mac/linux) or Command Prompt(windows):

# %% [markdown]
#             jupyter notebook

# %% [markdown]
# **The Following is the output when you run the command**

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2022-20-10.png](attachment:Screenshot%20from%202018-05-11%2022-20-10.png)

# %% [markdown]
# * It automatically opens the jupyter in your default browser with files tab opened.
# * Else if you couldn't see it opening, copy the url in the last line and run it from the browser you wish.

# %% [markdown]
# * Make a note that you could access only files only from the current directory, from which you are running the **jupyter notebook** command.

# %% [markdown]
# * In windows, you could search for jupyter notebook in start menu and click on it to open.
# * Make a note that this method defaults the directory as Documents Folder

# %% [markdown]
# See Running the Notebook (below link) for more details.
#
# https://jupyter.readthedocs.io/en/latest/running.html#running

# %% [markdown]
# <a id='5'></a>
# ## Creating a Notebook

# %% [markdown]
# * A new notebook may be created at any time, either from the dashboard, or using the File ‣ New menu option from within an active notebook.
# * The new notebook is created within the same directory and will open in a new browser tab.
# * It will also be reflected as a new entry in the notebook list on the dashboard.

# %% [markdown]
# ![new-notebook.gif](attachment:new-notebook.gif)

# %% [markdown]
# **Notebook user interface**

# %% [markdown]
# ![blank-notebook-ui.png](attachment:blank-notebook-ui.png)

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2022-40-35.png](attachment:Screenshot%20from%202018-05-11%2022-40-35.png)

# %% [markdown]
# <a id='6'></a>
# ## Execute a notebook

# %% [markdown]
# * The notebook is capable of running code in a wide range of languages.
# * However, each notebook is associated with a single kernel.
# * This notebook is associated with the IPython kernel, therefor runs Python code.

# %% [markdown]
# **Code cells allow you to enter and run code**

# %% [markdown]
#                         Run a code cell using Shift-Enter or pressing the button in the toolbar above:
#
# ![Screenshot%20from%202018-05-11%2022-44-39.png](attachment:Screenshot%20from%202018-05-11%2022-44-39.png)

# %% [markdown]
# * There are two other keyboard shortcuts for running code:
#
#     * **Alt-Enter** runs the current cell and inserts a new one below.
#     * **Ctrl-Enter** run the current cell and enters command mode.

# %% [markdown]
# **Cell menu**
# * The “Cell” menu has a number of menu items for running code in different ways. These includes:
#
#     * Run and Select Below
#     * Run and Insert Below
#     * Run All
#     * Run All Above
#     * Run All Below

# %% [markdown]
# **Output is asynchronous**
# * All output is displayed asynchronously as it is generated in the Kernel.
# * If you execute the next cell, you will see the output one piece at a time, not all at the end.

# %% [markdown]
# <a id='7'></a>
# ## Some Special Features

# %% [markdown]
# <a id=''></a>
# ### Inserting an Image

# %% [markdown]
# **For example:**

# %% [markdown]
#     <img src='dteamlogo.jpg'>

# %% [markdown]
# <img src='data/dteamlogo.jpg'>

# %% [markdown]
# * Or by **Edit -> Insert Image**
#     * To directly embed the image into the notebook, so that no source file is needed

# %% [markdown]
# ![imageedit_1_2786149576.jpg](attachment:imageedit_1_2786149576.jpg)

# %% [markdown]
# <a id=''></a>
# ### Embedding Video

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("lXUQ-DdSDoE")

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2023-18-31.png](attachment:Screenshot%20from%202018-05-11%2023-18-31.png)

# %% [markdown]
# ### Tool Tip

# %% [markdown]
# * By hitting **shift + tab** key, One could see the information of methods, functions and objects.

# %%
import pandas as pd
pd.Series()
# Out:
# Series([], dtype: float64)

# %%
pd.DataFrame()

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2023-26-25.png](attachment:Screenshot%20from%202018-05-11%2023-26-25.png)

# %% [markdown]
# * You could also press tab, to list the methods of an object

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2023-25-48.png](attachment:Screenshot%20from%202018-05-11%2023-25-48.png)

# %% [markdown]
# <a id='8'></a>
# ## Markdowns

# %% [markdown]
# * Text can be added to Jupyter Notebooks using Markdown cells.
# * You can change the cell type to Markdown by using the Cell menu, the toolbar, or the key shortcut m.
# * Markdown is a popular markup language that is a superset of HTML.
# * Its specification can be found here:
#     * https://daringfireball.net/projects/markdown/

# %% [markdown]
# <a id=''></a>
# ### Headers

# %% [markdown]
# * You can add headings by starting a line with one (or multiple) # followed by a space, as in the following example:

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2022-51-41.png](attachment:Screenshot%20from%202018-05-11%2022-51-41.png)

# %% [markdown]
# <a id=''></a>
# ### Mathematical Equations

# %% [markdown]
# Courtesy of MathJax, you can include mathematical expressions both inline: $e^{i\pi} + 1 = 0$ and displayed:
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# **Inline expressions can be added by surrounding the latex code with $:**

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2022-54-42.png](attachment:Screenshot%20from%202018-05-11%2022-54-42.png)

# %% [markdown]
# **Expressions on their own line are surrounded by $$:**

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2022-54-47.png](attachment:Screenshot%20from%202018-05-11%2022-54-47.png)

# %% [markdown]
# * The following is a preliminary proposal for representing equations directly as HTML+ using an SGML-based notation, inspired by the approach taken by LaTeX.

# %% [markdown]
# Consider the equation:

# %% [markdown]
# ![htmlplus_AFrame_1.gif](attachment:htmlplus_AFrame_1.gif)

# %% [markdown]
# This can be represented as:
#
#     <math>
#         H(s) = ∫<sub>0</sub><sup>∞</sup> e<sup>-st</sup> h(t) dt
#     </math>

# %% [markdown]
# <math>
# 	H(s) = ∫<sub>0</sub><sup>∞</sup> e<sup>-st</sup> h(t) dt
# </math>

# %% [markdown]
# <a id='9'></a>
# ### NBConvert

# %% [markdown]
# * Convert Notebooks to other formats

# %% [markdown]
# * Using nbconvert enables:
#
#     * presentation of information in familiar formats, such as PDF.
#     * publishing of research using LaTeX and opens the door for embedding notebooks in papers.
#     * collaboration with others who may not use the notebook in their work.
#     * sharing contents with many people via the web using HTML.

# %% [markdown]
# * Overall, notebook conversion and the nbconvert tool give scientists and researchers the flexibility to deliver information in a timely way across different formats.

# %% [markdown]
# <a id='10'></a>
# ### Environment and Jupyter

# %% [markdown]
# **Why Using virtual environments is important?**
#
#
#     * It helps to maintain your system clean since you don’t install system-wide libraries that you are only going to need in a small project
#
#     * It allows you to use a certain version of a library for one project and another version for another project: if you install the library system-wide and don’t use venv, then you can only use one version of the library
#
#     * It helps reproducible research: you work hard on your project, you write a paper on it because you are an academic research and then you release the code; one year later, the libraries you used are outed but your package still works: by listing the particular versions the you used, another researcher can set up a new virtual environment and use those outdated libraries to reproduce your work

# %% [markdown]
# * Lets assume that you have conda installed on your machine.
# * Then what we need to do is create the environment.
# * You can specify python version like python=3.4.
# * After creating we can activate the environment and install manually whatever we need.

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2023-54-06.png](attachment:Screenshot%20from%202018-05-11%2023-54-06.png)

# %% [markdown]
# ### You can also export the environment.yaml

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2023-53-54.png](attachment:Screenshot%20from%202018-05-11%2023-53-54.png)

# %% [markdown]
# * If you are working with jupyter notebooks, the easiest way to export your environment into jupyter is installing nb_conda within your environment.
# * It would pull many dependencies

# %% [markdown]
# ![Screenshot%20from%202018-05-11%2023-53-59.png](attachment:Screenshot%20from%202018-05-11%2023-53-59.png)

# %% [markdown]
# * You could the environments running in the jupyter

# %% [markdown]
# ![otShT.png](attachment:otShT.png)

# %% [markdown]
# <a id='11'></a>
# ## Kernel

# %% [markdown]
# * A notebook kernel is a “computational engine” that executes the code contained in a Notebook document.
# * The ipython kernel executes python code.
# * Kernels for many other languages exist.
#
#
# * When you open a Notebook document, the associated kernel is automatically launched.
# * When the notebook is executed (either cell-by-cell or with menu Cell -> Run All), the kernel performs the computation and produces the results.
# * Depending on the type of computations, the kernel may consume significant CPU and RAM.
# * Note that the RAM is not released until the kernel is shut-down.

# %% [markdown]
# ![robotlab-jupyter-11-638.jpg](attachment:robotlab-jupyter-11-638.jpg)

# %% [markdown]
# **In the following link, the list of supported kernels are listed down.**
# * https://github.com/jupyter/jupyter/wiki/Jupyter-kernels

# %% [markdown]
# <a id=''></a>
# ## References

# %% [markdown]
# * https://github.com/jupyter/jupyter/wiki/Jupyter-kernels
# * http://jupyter-notebook.readthedocs.io/en/stable/notebook.html
# * https://www.esri.com/arcgis-blog/products/api-python/analytics/three-reasons-to-use-jupyter-notebooks-as-a-gis-user/
# * http://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Running%20Code.html
# * http://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html
# * https://evcu.github.io/notes/condaEnv/
# * https://conda.io/docs/user-guide/tasks/manage-environments.html
